# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold, cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_recall_fscore_support

# %%
# 1. 데이터 불러오기
data = pd.read_csv('azdigar nav sartirovka+0 delete.csv')

# %%
columns = [
    ('w08chronic_a', '고혈압'), 
    ('w08chronic_b', '당뇨병'),
    ('w08chronic_c', '암 및 악성종양'),
    ('w08chronic_d', '만성 폐질환'),
    ('w08chronic_e', '간질환'),
    ('w08chronic_f', '심장질환'),
    ('w08chronic_g', '뇌혈관질환'),
    ('w08chronic_h', '정신과적 질환'),
    ('w08chronic_i', '관절염 또는 류마티스'),
    ('w08chronic_k', '소화기계 질환'),
    ('w08chronic_l', '디스크 진단')
    ('w08chronic_m', '지매')

]

# %%
# Target 컬럼명만 추출
target_columns = [col[0] for col in columns]

# %%
# 3. 데이터 클리닝 - 'w08chronic_m'에서 값이 3인 행 제거
cleaned_data = data[data['w08chronic_m'] != 3]

# %%
# 4. 인코딩 처리 (1 -> 0 (no), 5 -> 1 (yes))
cleaned_data[target_columns] = cleaned_data[target_columns].replace({1: 0, 5: 1})
# Out:
# C:\Users\azamj\AppData\Local\Temp\ipykernel_9380\663519800.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_data[target_columns] = cleaned_data[target_columns].replace({1: 0, 5: 1})

# %%
# 5. 피처와 타겟 정의
X = cleaned_data.drop(columns=target_columns)
y_all = cleaned_data[target_columns]

# %%
# 6. 데이터 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# 7. KFold 교차 검증 설정
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# 8. 모델 정의
random_forest = MultiOutputClassifier(RandomForestClassifier(random_state=42))
decision_tree = MultiOutputClassifier(DecisionTreeClassifier(random_state=42))

# %%
# 9. 모델별 예측값 얻기
rf_pred = cross_val_predict(random_forest, X_scaled, y_all, cv=kf)
dt_pred = cross_val_predict(decision_tree, X_scaled, y_all, cv=kf)

# %%
# 10. 전체 정확도 계산
rf_accuracy = accuracy_score(y_all, rf_pred)
dt_accuracy = accuracy_score(y_all, dt_pred)

# 11. Precision, Recall, F1-Score 계산 (Random Forest & Decision Tree)
def calculate_metrics(y_true, y_pred, model_name):
    results = []
    for i, (col, desc) in enumerate(columns):
        precision, recall, f1, _ = precision_recall_fscore_support(y_true[col], y_pred[:, i], average='binary')
        accuracy = accuracy_score(y_true[col], y_pred[:, i])  # 정확도 계산
        results.append({
            'Target': col,
            'Description': desc,
            'Model': model_name,
            'Precision': precision,
            'Recall': recall,
            'F1-Score': f1,
             'Accuracy': accuracy  # 정확도 추가
        })
    return results

rf_results = calculate_metrics(y_all, rf_pred, 'RandomForest')
dt_results = calculate_metrics(y_all, dt_pred, 'DecisionTree')

# %%
# 12. Micro F1, Macro F1, Weighted F1 계산
rf_micro_f1 = f1_score(y_all, rf_pred, average='micro')
rf_macro_f1 = f1_score(y_all, rf_pred, average='macro')
rf_weighted_f1 = f1_score(y_all, rf_pred, average='weighted')

dt_micro_f1 = f1_score(y_all, dt_pred, average='micro')
dt_macro_f1 = f1_score(y_all, dt_pred, average='macro')
dt_weighted_f1 = f1_score(y_all, dt_pred, average='weighted')

# %%
# 13. 결과 DataFrame으로 변환 및 출력
rf_result_table = pd.DataFrame(rf_results)
dt_result_table = pd.DataFrame(dt_results)

rf_result_table = rf_result_table.style.set_properties(**{'text-align': 'left'})
rf_result_table = rf_result_table.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])

dt_result_table = dt_result_table.style.set_properties(**{'text-align': 'left'})
dt_result_table = dt_result_table.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])


print("RandomForest Results")
display(rf_result_table)
print("DecisionTree Results")
display(dt_result_table)
# Out:
# RandomForest Results
# <style type="text/css">
# #T_64b74 th {
#   text-align: left;
# }
# #T_64b74_row0_col0, #T_64b74_row0_col1, #T_64b74_row0_col2, #T_64b74_row0_col3, #T_64b74_row0_col4, #T_64b74_row0_col5, #T_64b74_row0_col6, #T_64b74_row1_col0, #T_64b74_row1_col1, #T_64b74_row1_col2, #T_64b74_row1_col3, #T_64b74_row1_col4, #T_64b74_row1_col5, #T_64b74_row1_col6, #T_64b74_row2_col0, #T_64b74_row2_col1, #T_64b74_row2_col2, #T_64b74_row2_col3, #T_64b74_row2_col4, #T_64b74_row2_col5, #T_64b74_row2_col6, #T_64b74_row3_col0, #T_64b74_row3_col1, #T_64b74_row3_col2, #T_64b74_row3_col3, #T_64b74_row3_col4, #T_64b74_row3_col5, #T_64b74_row3_col6, #T_64b74_row4_col0, #T_64b74_row4_col1, #T_64b74_row4_col2, #T_64b74_row4_col3, #T_64b74_row4_col4, #T_64b74_row4_col5, #T_64b74_row4_col6, #T_64b74_row5_col0, #T_64b74_row5_col1, #T_64b74_row5_col2, #T_64b74_row5_col3, #T_64b74_row5_col4, #T_64b74_row5_col5, #T_64b74_row5_col6, #T_64b74_row6_col0, #T_64b74_row6_col1, #T_64b74_row6_col2, #T_64b74_row6_col3, #T_64b74_row6_col4, #T_64b74_row6_col5, #T_64b74_row6_col6, #T_64b74_row7_col0, #T_64b74_row7_col1, #T_64b74_row7_col2, #T_64b74_row7_col3, #T_64b74_row7_col4, #T_64b74_row7_col5, #T_64b74_row7_col6, #T_64b74_row8_col0, #T_64b74_row8_col1, #T_64b74_row8_col2, #T_64b74_row8_col3, #T_64b74_row8_col4, #T_64b74_row8_col5, #T_64b74_row8_col6, #T_64b74_row9_col0, #T_64b74_row9_col1, #T_64b74_row9_col2, #T_64b74_row9_col3, #T_64b74_row9_col4, #T_64b74_row9_col5, #T_64b74_row9_col6, #T_64b74_row10_col0, #T_64b74_row10_col1, #T_64b74_row10_col2, #T_64b74_row10_col3, #T_64b74_row10_col4, #T_64b74_row10_col5, #T_64b74_row10_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_64b74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64b74_level0_col0" class="col_heading level0 col0" >Target</th>
#       <th id="T_64b74_level0_col1" class="col_heading level0 col1" >Description</th>
#       <th id="T_64b74_level0_col2" class="col_heading level0 col2" >Model</th>
#       <th id="T_64b74_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_64b74_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_64b74_level0_col5" class="col_heading level0 col5" >F1-Score</th>
#       <th id="T_64b74_level0_col6" class="col_heading level0 col6" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64b74_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64b74_row0_col0" class="data row0 col0" >w08chronic_a</td>
#       <td id="T_64b74_row0_col1" class="data row0 col1" >고혈압</td>
#       <td id="T_64b74_row0_col2" class="data row0 col2" >RandomForest</td>
#       <td id="T_64b74_row0_col3" class="data row0 col3" >0.787330</td>
#       <td id="T_64b74_row0_col4" class="data row0 col4" >0.663841</td>
#       <td id="T_64b74_row0_col5" class="data row0 col5" >0.720331</td>
#       <td id="T_64b74_row0_col6" class="data row0 col6" >0.731508</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64b74_row1_col0" class="data row1 col0" >w08chronic_b</td>
#       <td id="T_64b74_row1_col1" class="data row1 col1" >당뇨병</td>
#       <td id="T_64b74_row1_col2" class="data row1 col2" >RandomForest</td>
#       <td id="T_64b74_row1_col3" class="data row1 col3" >0.781843</td>
#       <td id="T_64b74_row1_col4" class="data row1 col4" >0.990393</td>
#       <td id="T_64b74_row1_col5" class="data row1 col5" >0.873847</td>
#       <td id="T_64b74_row1_col6" class="data row1 col6" >0.776551</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_64b74_row2_col0" class="data row2 col0" >w08chronic_c</td>
#       <td id="T_64b74_row2_col1" class="data row2 col1" >암 및 악성종양</td>
#       <td id="T_64b74_row2_col2" class="data row2 col2" >RandomForest</td>
#       <td id="T_64b74_row2_col3" class="data row2 col3" >0.921837</td>
#       <td id="T_64b74_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_64b74_row2_col5" class="data row2 col5" >0.959329</td>
#       <td id="T_64b74_row2_col6" class="data row2 col6" >0.921837</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_64b74_row3_col0" class="data row3 col0" >w08chronic_d</td>
#       <td id="T_64b74_row3_col1" class="data row3 col1" >만성 폐질환</td>
#       <td id="T_64b74_row3_col2" class="data row3 col2" >RandomForest</td>
#       <td id="T_64b74_row3_col3" class="data row3 col3" >0.969088</td>
#       <td id="T_64b74_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_64b74_row3_col5" class="data row3 col5" >0.984301</td>
#       <td id="T_64b74_row3_col6" class="data row3 col6" >0.969088</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_64b74_row4_col0" class="data row4 col0" >w08chronic_e</td>
#       <td id="T_64b74_row4_col1" class="data row4 col1" >간질환</td>
#       <td id="T_64b74_row4_col2" class="data row4 col2" >RandomForest</td>
#       <td id="T_64b74_row4_col3" class="data row4 col3" >0.970192</td>
#       <td id="T_64b74_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_64b74_row4_col5" class="data row4 col5" >0.984871</td>
#       <td id="T_64b74_row4_col6" class="data row4 col6" >0.970192</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_64b74_row5_col0" class="data row5 col0" >w08chronic_f</td>
#       <td id="T_64b74_row5_col1" class="data row5 col1" >심장질환</td>
#       <td id="T_64b74_row5_col2" class="data row5 col2" >RandomForest</td>
#       <td id="T_64b74_row5_col3" class="data row5 col3" >0.901744</td>
#       <td id="T_64b74_row5_col4" class="data row5 col4" >1.000000</td>
#       <td id="T_64b74_row5_col5" class="data row5 col5" >0.948334</td>
#       <td id="T_64b74_row5_col6" class="data row5 col6" >0.901744</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_64b74_row6_col0" class="data row6 col0" >w08chronic_g</td>
#       <td id="T_64b74_row6_col1" class="data row6 col1" >뇌혈관질환</td>
#       <td id="T_64b74_row6_col2" class="data row6 col2" >RandomForest</td>
#       <td id="T_64b74_row6_col3" class="data row6 col3" >0.944960</td>
#       <td id="T_64b74_row6_col4" class="data row6 col4" >0.999299</td>
#       <td id="T_64b74_row6_col5" class="data row6 col5" >0.971370</td>
#       <td id="T_64b74_row6_col6" class="data row6 col6" >0.944359</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_64b74_row7_col0" class="data row7 col0" >w08chronic_h</td>
#       <td id="T_64b74_row7_col1" class="data row7 col1" >정신과적 질환</td>
#       <td id="T_64b74_row7_col2" class="data row7 col2" >RandomForest</td>
#       <td id="T_64b74_row7_col3" class="data row7 col3" >0.954295</td>
#       <td id="T_64b74_row7_col4" class="data row7 col4" >1.000000</td>
#       <td id="T_64b74_row7_col5" class="data row7 col5" >0.976613</td>
#       <td id="T_64b74_row7_col6" class="data row7 col6" >0.954295</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_64b74_row8_col0" class="data row8 col0" >w08chronic_i</td>
#       <td id="T_64b74_row8_col1" class="data row8 col1" >관절염 또는 류마티스</td>
#       <td id="T_64b74_row8_col2" class="data row8 col2" >RandomForest</td>
#       <td id="T_64b74_row8_col3" class="data row8 col3" >0.804517</td>
#       <td id="T_64b74_row8_col4" class="data row8 col4" >0.926181</td>
#       <td id="T_64b74_row8_col5" class="data row8 col5" >0.861073</td>
#       <td id="T_64b74_row8_col6" class="data row8 col6" >0.779201</td>
#     </tr>
#     <tr>
#       <th id="T_64b74_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_64b74_row9_col0" class="data row9 col0" >w08chronic_k</td>
#       <td id="T_64b74_row9_col1" class="data row9 col1" >소화기계 질환</td>
#       <td id="T_64b74_row9_col2" class="data row9 col2" >RandomForest</td>
# DecisionTree Results
# <style type="text/css">
# #T_381f9 th {
#   text-align: left;
# }
# #T_381f9_row0_col0, #T_381f9_row0_col1, #T_381f9_row0_col2, #T_381f9_row0_col3, #T_381f9_row0_col4, #T_381f9_row0_col5, #T_381f9_row0_col6, #T_381f9_row1_col0, #T_381f9_row1_col1, #T_381f9_row1_col2, #T_381f9_row1_col3, #T_381f9_row1_col4, #T_381f9_row1_col5, #T_381f9_row1_col6, #T_381f9_row2_col0, #T_381f9_row2_col1, #T_381f9_row2_col2, #T_381f9_row2_col3, #T_381f9_row2_col4, #T_381f9_row2_col5, #T_381f9_row2_col6, #T_381f9_row3_col0, #T_381f9_row3_col1, #T_381f9_row3_col2, #T_381f9_row3_col3, #T_381f9_row3_col4, #T_381f9_row3_col5, #T_381f9_row3_col6, #T_381f9_row4_col0, #T_381f9_row4_col1, #T_381f9_row4_col2, #T_381f9_row4_col3, #T_381f9_row4_col4, #T_381f9_row4_col5, #T_381f9_row4_col6, #T_381f9_row5_col0, #T_381f9_row5_col1, #T_381f9_row5_col2, #T_381f9_row5_col3, #T_381f9_row5_col4, #T_381f9_row5_col5, #T_381f9_row5_col6, #T_381f9_row6_col0, #T_381f9_row6_col1, #T_381f9_row6_col2, #T_381f9_row6_col3, #T_381f9_row6_col4, #T_381f9_row6_col5, #T_381f9_row6_col6, #T_381f9_row7_col0, #T_381f9_row7_col1, #T_381f9_row7_col2, #T_381f9_row7_col3, #T_381f9_row7_col4, #T_381f9_row7_col5, #T_381f9_row7_col6, #T_381f9_row8_col0, #T_381f9_row8_col1, #T_381f9_row8_col2, #T_381f9_row8_col3, #T_381f9_row8_col4, #T_381f9_row8_col5, #T_381f9_row8_col6, #T_381f9_row9_col0, #T_381f9_row9_col1, #T_381f9_row9_col2, #T_381f9_row9_col3, #T_381f9_row9_col4, #T_381f9_row9_col5, #T_381f9_row9_col6, #T_381f9_row10_col0, #T_381f9_row10_col1, #T_381f9_row10_col2, #T_381f9_row10_col3, #T_381f9_row10_col4, #T_381f9_row10_col5, #T_381f9_row10_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_381f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_381f9_level0_col0" class="col_heading level0 col0" >Target</th>
#       <th id="T_381f9_level0_col1" class="col_heading level0 col1" >Description</th>
#       <th id="T_381f9_level0_col2" class="col_heading level0 col2" >Model</th>
#       <th id="T_381f9_level0_col3" class="col_heading level0 col3" >Precision</th>
#       <th id="T_381f9_level0_col4" class="col_heading level0 col4" >Recall</th>
#       <th id="T_381f9_level0_col5" class="col_heading level0 col5" >F1-Score</th>
#       <th id="T_381f9_level0_col6" class="col_heading level0 col6" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_381f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_381f9_row0_col0" class="data row0 col0" >w08chronic_a</td>
#       <td id="T_381f9_row0_col1" class="data row0 col1" >고혈압</td>
#       <td id="T_381f9_row0_col2" class="data row0 col2" >DecisionTree</td>
#       <td id="T_381f9_row0_col3" class="data row0 col3" >0.676433</td>
#       <td id="T_381f9_row0_col4" class="data row0 col4" >0.675286</td>
#       <td id="T_381f9_row0_col5" class="data row0 col5" >0.675859</td>
#       <td id="T_381f9_row0_col6" class="data row0 col6" >0.662619</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_381f9_row1_col0" class="data row1 col0" >w08chronic_b</td>
#       <td id="T_381f9_row1_col1" class="data row1 col1" >당뇨병</td>
#       <td id="T_381f9_row1_col2" class="data row1 col2" >DecisionTree</td>
#       <td id="T_381f9_row1_col3" class="data row1 col3" >0.804498</td>
#       <td id="T_381f9_row1_col4" class="data row1 col4" >0.788358</td>
#       <td id="T_381f9_row1_col5" class="data row1 col5" >0.796347</td>
#       <td id="T_381f9_row1_col6" class="data row1 col6" >0.684919</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_381f9_row2_col0" class="data row2 col0" >w08chronic_c</td>
#       <td id="T_381f9_row2_col1" class="data row2 col1" >암 및 악성종양</td>
#       <td id="T_381f9_row2_col2" class="data row2 col2" >DecisionTree</td>
#       <td id="T_381f9_row2_col3" class="data row2 col3" >0.925980</td>
#       <td id="T_381f9_row2_col4" class="data row2 col4" >0.916886</td>
#       <td id="T_381f9_row2_col5" class="data row2 col5" >0.921411</td>
#       <td id="T_381f9_row2_col6" class="data row2 col6" >0.855818</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_381f9_row3_col0" class="data row3 col0" >w08chronic_d</td>
#       <td id="T_381f9_row3_col1" class="data row3 col1" >만성 폐질환</td>
#       <td id="T_381f9_row3_col2" class="data row3 col2" >DecisionTree</td>
#       <td id="T_381f9_row3_col3" class="data row3 col3" >0.969662</td>
#       <td id="T_381f9_row3_col4" class="data row3 col4" >0.961267</td>
#       <td id="T_381f9_row3_col5" class="data row3 col5" >0.965446</td>
#       <td id="T_381f9_row3_col6" class="data row3 col6" >0.933319</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_381f9_row4_col0" class="data row4 col0" >w08chronic_e</td>
#       <td id="T_381f9_row4_col1" class="data row4 col1" >간질환</td>
#       <td id="T_381f9_row4_col2" class="data row4 col2" >DecisionTree</td>
#       <td id="T_381f9_row4_col3" class="data row4 col3" >0.970948</td>
#       <td id="T_381f9_row4_col4" class="data row4 col4" >0.958352</td>
#       <td id="T_381f9_row4_col5" class="data row4 col5" >0.964609</td>
#       <td id="T_381f9_row4_col6" class="data row4 col6" >0.931773</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_381f9_row5_col0" class="data row5 col0" >w08chronic_f</td>
#       <td id="T_381f9_row5_col1" class="data row5 col1" >심장질환</td>
#       <td id="T_381f9_row5_col2" class="data row5 col2" >DecisionTree</td>
#       <td id="T_381f9_row5_col3" class="data row5 col3" >0.905871</td>
#       <td id="T_381f9_row5_col4" class="data row5 col4" >0.895446</td>
#       <td id="T_381f9_row5_col5" class="data row5 col5" >0.900628</td>
#       <td id="T_381f9_row5_col6" class="data row5 col6" >0.821815</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_381f9_row6_col0" class="data row6 col0" >w08chronic_g</td>
#       <td id="T_381f9_row6_col1" class="data row6 col1" >뇌혈관질환</td>
#       <td id="T_381f9_row6_col2" class="data row6 col2" >DecisionTree</td>
#       <td id="T_381f9_row6_col3" class="data row6 col3" >0.949528</td>
#       <td id="T_381f9_row6_col4" class="data row6 col4" >0.941094</td>
#       <td id="T_381f9_row6_col5" class="data row6 col5" >0.945292</td>
#       <td id="T_381f9_row6_col6" class="data row6 col6" >0.897108</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_381f9_row7_col0" class="data row7 col0" >w08chronic_h</td>
#       <td id="T_381f9_row7_col1" class="data row7 col1" >정신과적 질환</td>
#       <td id="T_381f9_row7_col2" class="data row7 col2" >DecisionTree</td>
#       <td id="T_381f9_row7_col3" class="data row7 col3" >0.959126</td>
#       <td id="T_381f9_row7_col4" class="data row7 col4" >0.944702</td>
#       <td id="T_381f9_row7_col5" class="data row7 col5" >0.951859</td>
#       <td id="T_381f9_row7_col6" class="data row7 col6" >0.908810</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_381f9_row8_col0" class="data row8 col0" >w08chronic_i</td>
#       <td id="T_381f9_row8_col1" class="data row8 col1" >관절염 또는 류마티스</td>
#       <td id="T_381f9_row8_col2" class="data row8 col2" >DecisionTree</td>
#       <td id="T_381f9_row8_col3" class="data row8 col3" >0.800961</td>
#       <td id="T_381f9_row8_col4" class="data row8 col4" >0.797370</td>
#       <td id="T_381f9_row8_col5" class="data row8 col5" >0.799161</td>
#       <td id="T_381f9_row8_col6" class="data row8 col6" >0.703908</td>
#     </tr>
#     <tr>
#       <th id="T_381f9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_381f9_row9_col0" class="data row9 col0" >w08chronic_k</td>
#       <td id="T_381f9_row9_col1" class="data row9 col1" >소화기계 질환</td>
#       <td id="T_381f9_row9_col2" class="data row9 col2" >DecisionTree</td>

# %%
# 14. 전체 결과 출력
print(f"RandomForest Overall Accuracy: {rf_accuracy}")
print(f"RandomForest Micro F1: {rf_micro_f1}, Macro F1: {rf_macro_f1}, Weighted F1: {rf_weighted_f1}")
print(f"DecisionTree Overall Accuracy: {dt_accuracy}")
print(f"DecisionTree Micro F1: {dt_micro_f1}, Macro F1: {dt_macro_f1}, Weighted F1: {dt_weighted_f1}")
# Out:
# RandomForest Overall Accuracy: 0.3634356370059616
# RandomForest Micro F1: 0.945454948023337, Macro F1: 0.9328702355667225, Weighted F1: 0.945337357893712
# DecisionTree Overall Accuracy: 0.22676087436520204
# DecisionTree Micro F1: 0.9125848036458393, Macro F1: 0.8980870089328307, Weighted F1: 0.9126091796761371
